# %%
import pandas as pd
import tqdm

# %% [markdown]
# # AHV-IV MEMENTO

# %%
df = pd.read_csv("indexing/data/to_upsert/ahv_iv_memento/ahv_iv_de_fr_it_tags_subtopics_llm_EMBED.csv")
df.rename(columns={"text_summary": "summary_embedding"}, inplace=True)
len(df)

# %%
df.head()

# %%
df.to_csv("indexing/data/to_upsert/ahv_iv_memento/ahv_iv_de_fr_it_tags_subtopics_llm_EMBED.csv", index=None)

# %% [markdown]
# # EAK - AHV LERNBAUSTEIN 2024

# %%
df = pd.read_csv("indexing/data/to_upsert/AHV_Lernbaustein_2024/AHV_Lernbaustein_2024_tags_llm_EMBED.csv")
df.rename(columns={"text_summary": "summary_embedding"}, inplace=True)
len(df)

# %%
df.head()

# %%
df.to_csv("indexing/data/to_upsert/AHV_Lernbaustein_2024/AHV_Lernbaustein_2024_tags_llm_EMBED.csv", index=None)

# %% [markdown]
# # EAK PRAXISLEITFADEN 2024

# %%
df = pd.read_csv("indexing/data/to_upsert/Guide_Pratique_CAF_CFC/guide_pratique_caf_cfc_de_tags_llm.csv")
len(df)

# %%
df.head()

# %% [markdown]
# # AKIS

# %%
df = pd.read_csv("indexing/data/zas_eak_copilot/akis/akis_EMBED_2.csv")
len(df)

# %%
df.head()

# %% [markdown]
# # EAK ADMIN CH

# %%
df = pd.read_csv("indexing/data/to_upsert/eak_admin_ch/eak_admin_ch_de_fr_tags_NEW.csv")
len(df)

# %%
df.head()

# %% [markdown]
# # FEDLEX

# %%
df = pd.read_csv("indexing/data/to_upsert/fedlex/lavs.csv")
len(df)

# %%
df.head()

# %% [markdown]
# # OFAS

# %%
df = pd.read_csv("../preprocessing/output/ofas.csv")
len(df)
# Out:
# 57

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://sozialversicherungen.admin.ch/it/d/690...
# 1  https://sozialversicherungen.admin.ch/it/d/695...
# 2  https://sozialversicherungen.admin.ch/it/d/694...
# 3  https://sozialversicherungen.admin.ch/it/d/692...
# 4  https://sozialversicherungen.admin.ch/it/d/695...
#
#                                                 text language tags subtopics  \
# 0  1 Panoramica delle direttive sui contributi, s...       it   []        []
# 1  Direttive sull’obbligo assicurativo nell’AVS/A...       it   []        []
# 2  Direttive sul salario determinante nell ’AVS/A...       it   []        []
# 3  Direttive sulla riscossione dei contributi nel...       it   []        []
# 4  Direttive sui contributi dei lavoratori indipe...       it   []        []
#
#    summary      doctype organizations  hyq  hyq_declarative
# 0      NaN  context_doc          OFAS  NaN              NaN
# 1      NaN  context_doc          OFAS  NaN              NaN
# 2      NaN  context_doc          OFAS  NaN              NaN
# 3      NaN  context_doc          OFAS  NaN              NaN
# 4      NaN  context_doc          OFAS  NaN              NaN

# %% [markdown]
# # AUTOCOMPLETE

# %%
df = pd.read_csv("indexing/data/to_upsert/autocomplete/question.csv")

df["text_embedding"] = None

len(df)

# %%
df.head()

# %%
for i, row in tqdm.tqdm(df.iterrows()):

    embeddings = await get_embedding([row.text])

    df.loc[i, "text_embedding"] = str(embeddings[0].embedding)

# %%
df.tail()

# %%
df.to_csv("indexing/data/to_upsert/autocomplete/question_EMBED.csv", index=None)

# %%
df.to_csv("indexing/data/to_upsert/autocomplete/eak_admin_ch_de_fr_tags_EMBED.csv", index=None)

# %% [markdown]
# # EMBEDDING

# %%
MAX_INPUT_TOKENS = 8191

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..', '..', 'src', 'copilot', 'app')))

# Now you can import the function
from utils.embedding import get_embedding
# Out:
# c:\Users\deyan\cdc\ZAS-EAK-CopilotGPT\venv\Lib\site-packages\pydantic\_internal\_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %%
df["text_embedding"] = None
df["tags_embedding"] = None
df["subtopics_embedding"] = None
df["summary_embedding"] = None
df["hyq_embedding"] = None
df["hyq_declarative_embedding"] = None

# %%
tags_embedding = await get_embedding(df.loc[0, "tags"]) # If tags are all the same

for i, row in tqdm.tqdm(df.iterrows()):

    try:
        tokens = tokenizer.encode(row.text)
        if len(tokens) > MAX_INPUT_TOKENS:
            truncated_text = tokenizer.decode(tokens[:MAX_INPUT_TOKENS])
            embeddings = await get_embedding(truncated_text)
        else:
            embeddings = await get_embedding(row.text)
    except Exception as e:
        embeddings = None

    df.loc[i, "text_embedding"] = str(embeddings) if embeddings else None
    #df.loc[i, "summary_embedding"] = str(embeddings[1].embedding)
    #df.loc[i, "hyq_embedding"] = str(embeddings[2].embedding)
    #df.loc[i, "hyq_declarative_embedding"] = str(embeddings[3].embedding)
    #df.loc[i, "subtopics_embedding"] = str(embeddings[4].embedding)
    df.loc[i, "tags_embedding"] = str(tags_embedding)
# Out:
# 2025-03-03 16:25:41,391 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:41,391 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 0it [00:00, ?it/s]2025-03-03 16:25:42,487 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:42,489 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 1it [00:01,  1.10s/it]2025-03-03 16:25:43,024 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:43,026 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 2it [00:01,  1.30it/s]2025-03-03 16:25:43,887 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:43,888 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 3it [00:02,  1.23it/s]2025-03-03 16:25:44,698 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:44,700 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 4it [00:03,  1.23it/s]2025-03-03 16:25:45,387 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:45,389 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 5it [00:03,  1.30it/s]2025-03-03 16:25:46,099 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:46,103 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 6it [00:04,  1.33it/s]2025-03-03 16:25:47,197 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:47,198 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 7it [00:05,  1.16it/s]2025-03-03 16:25:47,934 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:47,937 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 8it [00:06,  1.22it/s]2025-03-03 16:25:48,436 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:48,438 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 9it [00:07,  1.38it/s]2025-03-03 16:25:48,877 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:48,879 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 10it [00:07,  1.57it/s]2025-03-03 16:25:49,171 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:49,173 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 11it [00:07,  1.88it/s]2025-03-03 16:25:49,844 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:25:49,846 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
#
- utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 49it [00:31,  1.71it/s]2025-03-03 16:26:13,220 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:13,222 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 50it [00:31,  1.60it/s]2025-03-03 16:26:13,688 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:13,689 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 51it [00:32,  1.73it/s]2025-03-03 16:26:14,213 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:14,215 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 52it [00:32,  1.78it/s]2025-03-03 16:26:14,631 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:14,632 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 53it [00:33,  1.93it/s]2025-03-03 16:26:15,118 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:15,122 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 54it [00:33,  1.96it/s]2025-03-03 16:26:15,758 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:15,761 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 55it [00:34,  1.82it/s]2025-03-03 16:26:16,397 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:16,399 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 56it [00:35,  1.74it/s]2025-03-03 16:26:16,718 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-03-03 16:26:16,719 - utils.embedding - INFO - Embedding successfull with model: text-embedding-3-small
# 57it [00:35,  1.61it/s]

# %%
df.tail()
# Out:
#                                                   url  \
# 52  https://sozialversicherungen.admin.ch/de/d/640...
# 53  https://sozialversicherungen.admin.ch/de/d/155...
# 54  https://sozialversicherungen.admin.ch/de/d/629...
# 55  https://sozialversicherungen.admin.ch/de/d/693...
# 56  https://sozialversicherungen.admin.ch/de/d/184...
#
#                                                  text language tags subtopics  \
# 52  Kreisschreiben über das Verfahren zur Leis- tu...       de   []        []
# 53  EDI BSV | Kreisschreiben zum Übergangsrecht de...       de   []        []
# 54  Erläuterungen zum Kreisschreiben über die Leis...       de   []        []
# 55  EDI BSV | Nachtrag 14 zur Wegleitung über die ...       de   []        []
# 56  Nachtrag 4 zum Kreisschreiben über das Verfahr...       de   []        []
#
#     summary      doctype organizations  hyq  hyq_declarative  \
# 52      NaN  context_doc          OFAS  NaN              NaN
# 53      NaN  context_doc          OFAS  NaN              NaN
# 54      NaN  context_doc          OFAS  NaN              NaN
# 55      NaN  context_doc          OFAS  NaN              NaN
# 56      NaN  context_doc          OFAS  NaN              NaN
#
#                                        text_embedding  \
# 52  [-0.004064788576215506, 0.036861587315797806, ...
# 53  [0.010609467513859272, 0.04923446848988533, 0....
# 54  [-0.04111221060156822, 0.04086235910654068, 0....
# 55  [-0.016585489735007286, 0.0013660902623087168,...
# 56  [-0.0021825614385306835, 0.024891218170523643,...
#
#                                        tags_embedding subtopics_embedding  \
# 52  [0.013414580374956131, 0.030635777860879898, 0...                None
# 53  [0.013414580374956131, 0.030635777860879898, 0...                None
# 54  [0.013414580374956131, 0.030635777860879898, 0...                None
# 55  [0.013414580374956131, 0.030635777860879898, 0...                None
# 56  [0.013414580374956131, 0.030635777860879898, 0...                None
#
#    summary_embedding hyq_embedding hyq_declarative_embedding
# 52              None          None                      None
# 53              None          None                      None
# 54              None          None                      None
# 55              None          None                      None
# 56              None          None                      None

# %%
df.head()

# %%
df.to_csv("indexing/data/zas_eak_copilot/akis/akis_EMBED_2.csv", index=None)

# %%
df = pd.read_csv("indexing/data/zas_eak_copilot/akis/akis_EMBED_2.csv")

# %%
df.tail()
